# %%
# %reset

# %%
import pandas as pd

apt_arv_dly = pd.read_excel('datasets/Airport_Arrival_ATFM_Delay(16-24).xlsx', sheet_name = 'DATA')

# %%
apts = pd.read_excel('datasets/Airports.xlsx')

# %%
apt_dpt_dly = pd.read_excel('datasets/All_Pre-Departure_Delay (20-23).xlsx', sheet_name = 'DATA')

# %%
apt_tfc = pd.read_excel('datasets/Airport_Traffic(16-24).xlsx', sheet_name = 'DATA')

# %%
# filtering all dataframes to the chosen airports ICAOS

apt_arv_dly = apt_arv_dly[apt_arv_dly['APT_ICAO'].isin(apts['ICAO'])]

apt_arv_dly.groupby('APT_ICAO').count()
# Out:
#           YEAR  MONTH_NUM  MONTH_MON  FLT_DATE  APT_NAME  STATE_NAME  \
# APT_ICAO
# EBBR      2953       2953       2953      2953      2953        2953
# EDDF      2953       2953       2953      2953      2953        2953
# EDDH      2953       2953       2953      2953      2953        2953
# EDDK      2953       2953       2953      2953      2953        2953
# EDDL      2953       2953       2953      2953      2953        2953
# EDDM      2953       2953       2953      2953      2953        2953
# EDDS      2938       2938       2938      2938      2938        2938
# EDDT      1774       1774       1774      1774      1774        1774
# EFHK      2953       2953       2953      2953      2953        2953
# EGAA      2945       2945       2945      2945      2945        2945
# EGCC      2953       2953       2953      2953      2953        2953
# EGGD      2947       2947       2947      2947      2947        2947
# ...
